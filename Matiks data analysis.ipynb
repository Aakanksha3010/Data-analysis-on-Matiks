# %%
#importing all libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd

url = "https://docs.google.com/spreadsheets/d/1NyFJYCi5wF8QD0FIfxlyvYKksnnbKExzXOjioE_1hWA/export?format=csv&gid=0"

df = pd.read_csv(url)
df.head()
# Out:
#                                 User_ID          Username  \
# 0  7280e6c4-6f7c-45dd-a8fc-c58389ea8e07  geoffreyanderson
# 1  23c48d4f-f5d0-4ff4-ba0f-2007441b9b57   riverachristian
# 2  cf8d530c-c137-4346-a78b-e76e36d45e2a        brownchris
# 3  47fcbe87-a1c1-40c3-b450-1b5692f61538     christopher90
# 4  0b620a32-9e77-4b4a-9931-f0b654bef095          vfreeman
#
#                       Email  Signup_Date   Country  Age  Gender Device_Type  \
# 0   haleymitchell@gmail.com  15-Dec-2024   Austria   22   Other      Mobile
# 1  masonmelissa@hotmail.com  07-Mar-2024     Gabon   22   Other          PC
# 2     mnichols@mcmillan.net  19-Oct-2023   Ireland   36  Female          PC
# 3         ttaylor@gmail.com  28-Sep-2023   Belarus   23   Other          PC
# 4        amanda80@gmail.com  09-Aug-2024  Slovenia   26   Other          PC
#
#   Game_Title  Total_Play_Sessions  Avg_Session_Duration_Min  \
# 0  MysticWar                   21                      5.78
# 1  QuestRaid                   22                     32.53
# 2  QuestRaid                   12                     21.55
# 3  QuestRaid                   19                     28.36
# 4  QuestRaid                   18                     17.63
#
#    Total_Hours_Played  In_Game_Purchases_Count  Total_Revenue_USD  \
# 0               38.41                        6              27.50
# 1              129.02                       10               2.50
# 2               62.50                        5              25.56
# 3               79.40                        4             132.25
# 4               86.70                        6              20.79
#
#     Last_Login Subscription_Tier Referral_Source Preferred_Game_Mode  \
# 0  19-May-2025            Silver    Social Media               Co-op
# 1  12-May-2025              Gold             Ads                Solo
# 2  03-May-2025            Silver         Organic                Solo
# 3  08-May-2025            Silver          Friend         Multiplayer
# 4  24-Apr-2025              Free          Friend         Multiplayer
#
#   Rank_Tier  Achievement_Score
# 0    Bronze               8721
# 1    Bronze               3572
# 2  Platinum               1060
# 3   Diamond               3591
# 4   Diamond               2666

# %%
#descriptive analysis

df.count()
# Out:
# User_ID                     10000
# Username                    10000
# Email                       10000
# Signup_Date                 10000
# Country                     10000
# Age                         10000
# Gender                      10000
# Device_Type                 10000
# Game_Title                  10000
# Total_Play_Sessions         10000
# Avg_Session_Duration_Min    10000
# Total_Hours_Played          10000
# In_Game_Purchases_Count     10000
# Total_Revenue_USD           10000
# Last_Login                  10000
# Subscription_Tier           10000
# Referral_Source             10000
# Preferred_Game_Mode         10000
# Rank_Tier                   10000
# Achievement_Score           10000
# dtype: int64

# %%
df.describe()
# Out:
#                 Age  Total_Play_Sessions  Avg_Session_Duration_Min  \
# count  10000.000000         10000.000000              10000.000000
# mean      31.063700            19.993900                 30.035238
# std       10.687547             4.492314                 10.062647
# min       13.000000             6.000000                 -5.640000
# 25%       22.000000            17.000000                 23.210000
# 50%       31.000000            20.000000                 29.860000
# 75%       40.000000            23.000000                 36.902500
# max       49.000000            42.000000                 75.620000
#
#        Total_Hours_Played  In_Game_Purchases_Count  Total_Revenue_USD  \
# count        10000.000000              10000.00000       10000.000000
# mean           100.216981                  4.97600          50.177466
# std             49.642141                  2.23623          49.600884
# min            -89.730000                  0.00000           0.000000
# 25%             66.490000                  3.00000          14.900000
# 50%            100.435000                  5.00000          34.760000
# 75%            133.900000                  6.00000          69.225000
# max            283.260000                 17.00000         428.590000
#
#        Achievement_Score
# count       10000.000000
# mean         5009.304400
# std          2895.010702
# min             0.000000
# 25%          2481.750000
# 50%          5067.000000
# 75%          7498.250000
# max          9997.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Total_Play_Sessions'].plot(kind='hist', bins=20, title='Total_Play_Sessions')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Avg_Session_Duration_Min'].plot(kind='hist', bins=20, title='Avg_Session_Duration_Min')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Total_Hours_Played'].plot(kind='hist', bins=20, title='Total_Hours_Played')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='Age', y='Total_Play_Sessions', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='Total_Play_Sessions', y='Avg_Session_Duration_Min', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='Avg_Session_Duration_Min', y='Total_Hours_Played', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='Total_Hours_Played', y='In_Game_Purchases_Count', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['Age'].plot(kind='line', figsize=(8, 4), title='Age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['Total_Play_Sessions'].plot(kind='line', figsize=(8, 4), title='Total_Play_Sessions')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['Avg_Session_Duration_Min'].plot(kind='line', figsize=(8, 4), title='Avg_Session_Duration_Min')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['Total_Hours_Played'].plot(kind='line', figsize=(8, 4), title='Total_Hours_Played')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.isnull()
# Out:
#       User_ID  Username  Email  Signup_Date  Country    Age  Gender  \
# 0       False     False  False        False    False  False   False
# 1       False     False  False        False    False  False   False
# 2       False     False  False        False    False  False   False
# 3       False     False  False        False    False  False   False
# 4       False     False  False        False    False  False   False
# ...       ...       ...    ...          ...      ...    ...     ...
# 9995    False     False  False        False    False  False   False
# 9996    False     False  False        False    False  False   False
# 9997    False     False  False        False    False  False   False
# 9998    False     False  False        False    False  False   False
# 9999    False     False  False        False    False  False   False
#
#       Device_Type  Game_Title  Total_Play_Sessions  Avg_Session_Duration_Min  \
# 0           False       False                False                     False
# 1           False       False                False                     False
# 2           False       False                False                     False
# 3           False       False                False                     False
# 4           False       False                False                     False
# ...           ...         ...                  ...                       ...
# 9995        False       False                False                     False
# 9996        False       False                False                     False
# 9997        False       False                False                     False
# 9998        False       False                False                     False
# 9999        False       False                False                     False
#
#       Total_Hours_Played  In_Game_Purchases_Count  Total_Revenue_USD  \
# 0                  False                    False              False
# 1                  False                    False              False
# 2                  False                    False              False
# 3                  False                    False              False
# 4                  False                    False              False
# ...                  ...                      ...                ...
# 9995               False                    False              False
# 9996               False                    False              False
# 9997               False                    False              False
# 9998               False                    False              False
# 9999               False                    False              False
#
#       Last_Login  Subscription_Tier  Referral_Source  Preferred_Game_Mode  \
# 0          False              False            False                False
# 1          False              False            False                False
# 2          False              False            False                False
# 3          False              False            False                False
# 4          False              False            False                False
# ...          ...                ...              ...                  ...
# 9995       False              False            False                False
# 9996       False              False            False                False
# 9997       False              False            False                False
# 9998       False              False            False                False
# 9999       False              False            False                False
#
#       Rank_Tier  Achievement_Score
# 0         False              False
# 1         False              False
# 2         False              False
# 3         False              False
# 4         False              False
# ...         ...                ...
# 9995      False              False
# 9996      False              False
# 9997      False              False
# 9998      False              False
# 9999      False              False
#
# [10000 rows x 20 columns]
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Signup_Date']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Signup_Date'}, axis=1)
#               .sort_values('Signup_Date', ascending=True))
#   xs = counted['Signup_Date']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('Signup_Date', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Signup_Date')
# _ = plt.ylabel('count()')

# %%
#

# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.45.1-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.2.0)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (11.2.1)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.29.4)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.13.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit) (3.1.44)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (1.39.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2025.4.26)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.24.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.45.1-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 62.3 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 109.1 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.6 MB/s eta 0:00:00
# Installing collected packages: watchdog, pydeck, streamlit
# Successfully installed pydeck-0.9.1 streamlit-1.45.1 watchdog-6.0.0

# %%
import streamlit as st
import seaborn as sns

# %%
st.header("📊 Key Metrics")
st.write("**Total Users:**", df['User_ID'].nunique())
st.write("**Total Revenue:** $", round(df['Total_Revenue_USD'].sum(), 2))
st.write("**Average Sessions per User:**", round(df['Total_Play_Sessions'].mean(), 2))

# Behavioral Pattern
st.header("📅 Behavioral Patterns")
st.bar_chart(df.groupby('Preferred_Game_Mode')['Total_Play_Sessions'].sum())

# Session vs Revenue Scatter
st.header("💰 Session Frequency vs Revenue")
fig1, ax1 = plt.subplots()
sns.scatterplot(data=df, x='Total_Play_Sessions', y='Total_Revenue_USD', hue='Device_Type', ax=ax1)
st.pyplot(fig1)
# Out:
# 2025-05-25 17:29:17.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:17.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:17.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:17.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:17.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:17.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:17.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:17.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:17.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:17.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:17.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:17.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:17.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:17.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:17.817 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:17.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:17.904 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:17.912 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:17.914 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:17.916 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:18.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:18.905 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 17:29:18.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.sidebar.header("🔎 Filter Data")
selected_device = st.sidebar.multiselect("Device", options=df['Device_Type'].unique(), default=df['Device_Type'].unique())
selected_mode = st.sidebar.multiselect("Preferred Mode", options=df['Preferred_Game_Mode'].unique(), default=df['Preferred_Game_Mode'].unique())


# Apply filters
df = df[df['Device_Type'].isin(selected_device) & df['Preferred_Game_Mode'].isin(selected_mode)]

print(df[df['Device_Type'].isin(selected_device) & df['Preferred_Game_Mode'].isin(selected_mode)])
# Out:
# 2025-05-25 20:18:43.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:18:43.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:18:43.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:18:43.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:18:43.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:18:43.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:18:43.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:18:43.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:18:43.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:18:43.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:18:43.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:18:43.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
#                                    User_ID          Username  \
# 0     7280e6c4-6f7c-45dd-a8fc-c58389ea8e07  geoffreyanderson
# 1     23c48d4f-f5d0-4ff4-ba0f-2007441b9b57   riverachristian
# 2     cf8d530c-c137-4346-a78b-e76e36d45e2a        brownchris
# 3     47fcbe87-a1c1-40c3-b450-1b5692f61538     christopher90
# 4     0b620a32-9e77-4b4a-9931-f0b654bef095          vfreeman
# ...                                    ...               ...
# 9995  27bb6b21-5e30-4d70-8732-232fe08219e0   rebeccaphillips
# 9996  726e019b-1992-442d-9879-07620da088d7    jimenezjeffery
# 9997  2532e569-359d-4841-84dd-be95ff8a93bf       graymatthew
# 9998  65991176-51e1-4ab6-9ec4-af8cba1969fd        brittany87
# 9999  736d469b-f23a-494d-b42f-26883c5f81ae     michaelgraham
#
#                               Email  Signup_Date         Country  Age  Gender  \
# 0           haleymitchell@gmail.com  15-Dec-2024         Austria   22   Other
# 1          masonmelissa@hotmail.com  07-Mar-2024           Gabon   22   Other
# 2             mnichols@mcmillan.net  19-Oct-2023         Ireland   36  Female
# 3                 ttaylor@gmail.com  28-Sep-2023         Belarus   23   Other
# 4                amanda80@gmail.com  09-Aug-2024        Slovenia   26   Other
# ...                             ...          ...             ...  ...     ...
# 9995              oflores@yahoo.com  01-Jun-2023          Panama   16    Male
# 9996  fcampbell@shelton-edwards.biz  02-Jul-2024            Fiji   28    Male
# 9997              tgarrett@king.com  15-Mar-2024         Bermuda   42    Male
# 9998          moorealyssa@gmail.com  09-Dec-2024  American Samoa   44  Female
# 9999          lindacarter@gmail.com  07-Sep-2023           Haiti   40  Female
#
#      Device_Type  Game_Title  Total_Play_Sessions  Avg_Session_Duration_Min  \
# 0         Mobile   MysticWar                   21                      5.78
# 1             PC   QuestRaid                   22                     32.53
# 2             PC   QuestRaid                   12                     21.55
# 3             PC   QuestRaid                   19                     28.36
# 4             PC   QuestRaid                   18                     17.63
# ...          ...         ...                  ...                       ...
# 9995     Console  BattleZone                   22                     31.98
# 9996          PC   QuestRaid                   25                     21.09
# 9997          PC  BattleZone                   28                     20.71
# 9998          PC   QuestRaid                   20                     16.66
# 9999      Mobile   MysticWar                   18                     26.31
#
#       Total_Hours_Played  In_Game_Purchases_Count  Total_Revenue_USD  \
# 0                  38.41                        6              27.50
# 1                 129.02                       10               2.50
# 2                  62.50                        5              25.56
# 3                  79.40                        4             132.25
# 4                  86.70                        6              20.79
# ...                  ...                      ...                ...
# 9995              139.86                        6              37.70
# 9996               91.56                        7              34.88
# 9997              138.75                        4               0.48
# 9998               85.05                        4              24.78
# 9999              116.67                        1              23.58
#
#        Last_Login Subscription_Tier Referral_Source Preferred_Game_Mode  \
# 0     19-May-2025            Silver    Social Media               Co-op
# 1     12-May-2025              Gold             Ads                Solo
# 2     03-May-2025            Silver         Organic                Solo
# 3     08-May-2025            Silver          Friend         Multiplayer
# 4     24-Apr-2025              Free          Friend         Multiplayer
# ...           ...               ...             ...                 ...
# 9995  13-May-2025          Platinum             Ads         Multiplayer
# 9996  29-Apr-2025              Gold             Ads                Solo
# 9997  22-Apr-2025              Gold         Organic                Solo
# 9998  19-May-2025            Silver    Social Media               Co-op
# 9999  02-May-2025          Platinum         Organic                Solo
#
#      Rank_Tier  Achievement_Score
# 0       Bronze               8721
# 1       Bronze               3572
# 2     Platinum               1060
# 3      Diamond               3591
# 4      Diamond               2666
# ...        ...                ...
# 9995    Silver                162
# 9996   Diamond                228
# 9997   Diamond               9948
# 9998  Platinum               3792
# 9999   Diamond               1545
#
# [10000 rows x 20 columns]

# %%
st.header("📊 Key Metrics")
st.metric("Total Users", df['User_ID'].nunique())
st.metric("Total Revenue ($)", round(df['Total_Revenue_USD'].sum(), 2))
st.metric("Avg Sessions/User", round(df['Total_Play_Sessions'].mean(), 2))

# Behavioral Pattern
st.header("📅 Behavioral Patterns")
st.bar_chart(df.groupby('Preferred_Game_Mode')['Total_Play_Sessions'].sum())

# Session vs Total_Revenue_USD Scatter
st.header("💰 Session Frequency vs Total_Revenue_USD")
fig1, ax1 = plt.subplots()
sns.scatterplot(data=df, x='Total_Play_Sessions', y='Total_Revenue_USD', hue='Device_Type', ax=ax1)
st.pyplot(fig1)

# Ensure Last_Login column is parsed correctly and safely
df['Last_Login'] = pd.to_datetime(df['Last_Login'], errors='coerce', dayfirst=True)

# Filter users who haven't logged in for 30+ days
cutoff_date = pd.Timestamp.now() - pd.Timedelta(days=30)
churn_df = df[df['Last_Login'] < cutoff_date]

# Drop rows where Last_Login couldn't be parsed (NaT)
churn_df = churn_df.dropna(subset=['Last_Login'])

# Output
st.write(f"Churned Users: {churn_df.shape[0]}")
st.dataframe(churn_df[['User_ID', 'Total_Play_Sessions', 'Last_Login']])
# Out:
# 2025-05-25 20:22:46.011 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:22:46.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:22:46.084 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:22:46.089 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:22:46.094 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:22:46.096 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:22:46.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:22:46.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:22:46.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:22:46.102 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:22:46.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:22:46.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:22:46.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:22:46.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:22:46.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:22:46.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:22:46.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:22:46.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:22:46.727 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:22:46.732 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:22:46.733 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
from sklearn.mixture import GaussianMixture

# %%
st.header("🔍 User Segmentation with GMM")

# Step 1: Prepare the data
features = ['Total_Play_Sessions', 'Total_Revenue_USD']
seg_data = df[features].dropna()

# Step 2: Fit GMM
gmm = GaussianMixture(n_components=3, random_state=42)
gmm.fit(seg_data)

features = ['Total_Play_Sessions', 'Total_Revenue_USD']
X = df[features].dropna()

gmm = GaussianMixture(n_components=3, random_state=42)
gmm.fit(X)

# Always predict using only the original features
labels = gmm.predict(X)
probs = gmm.predict_proba(X).max(axis=1)

# Append results safely
seg_data = X.copy()
seg_data['Cluster'] = labels
seg_data['Cluster Prob'] = probs
# Out:
# 2025-05-25 20:26:31.077 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:26:31.078 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
fig2, ax2 = plt.subplots()
sns.scatterplot(
    data=seg_data,
    x='Total_Play_Sessions',
    y='Total_Revenue_USD',
    hue='Cluster',
    palette='Set2',
    ax=ax2
)
st.pyplot(fig2)
# Out:
# 2025-05-25 20:26:41.474 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:26:42.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:26:42.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# Cohort Analysis
st.header("🗓️ Cohort Analysis")
df['Signup_Date'] = pd.to_datetime(df['Signup_Date'])
df['Cohort_Month'] = df['Signup_Date'].dt.to_period('M')
cohort_data = df.groupby(['Cohort_Month'])['User_ID'].nunique().reset_index()
cohort_data.columns = ['Cohort_Month', 'New Users']
fig3, ax3 = plt.subplots()
sns.barplot(data=cohort_data, x='Cohort_Month', y='New Users', ax=ax3)
plt.xticks(rotation=45)
st.pyplot(fig3)
# Out:
# 2025-05-25 20:30:13.079 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:30:13.081 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:30:13.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:30:13.387 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:30:13.388 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
funnel_stages = ['Signed_Up', 'Played_First_Game', 'Repeat_Session', 'Made_Purchase']

# Filter stages that exist in df.columns
stages_present = [stage for stage in funnel_stages if stage in df.columns]

funnel = pd.DataFrame({
    'Stage': stages_present,
    'Users': [df[stage].sum() for stage in stages_present]
})

# %%
# Deep Dive: Top Retention Users
st.header("🌟 High Retention Users")
high_retention = df[df['Total_Play_Sessions'] > df['Total_Play_Sessions'].quantile(0.9)]
st.dataframe(high_retention[['User_ID', 'Total_Revenue_USD', 'Total_Play_Sessions', 'Last_Login']])

# Deep Dive: Low Total_Revenue_USD but Active
st.header("📉 Active Users with Low Total_Revenue_USD")
low_Total_Revenue_USD_active = df[(df['Total_Revenue_USD'] < df['Total_Revenue_USD'].median()) & (df['Total_Play_Sessions'] > df['Total_Play_Sessions'].median())]
st.dataframe(low_Total_Revenue_USD_active[['User_ID', 'Total_Revenue_USD', 'Total_Play_Sessions']])
# Out:
# 2025-05-25 20:38:08.689 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:38:08.690 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:38:08.698 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:38:08.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:38:08.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:38:08.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:38:08.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-25 20:38:08.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# !git config --global user.email "aakankshagyan3010@gmail.com"

# %%
# Replace the URL below with your public repo URL
# !git clone https://github.com/Aakanksha3010/Data-analysis-on-Matiks.git
# Out:
# Cloning into 'Data-analysis-on-Matiks'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/Matiks data analysis.ipynb" "/content/Data-analysis-on-Matiks/"
# Out:
# cp: target 'analysis.ipynb' is not a directory
